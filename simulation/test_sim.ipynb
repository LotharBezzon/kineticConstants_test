# %%
import pandas as pd
import numpy as np

# %%
sim_data = pd.read_parquet('simulation_files/simulated_data_0.parquet')

# %%
sim_data
# Out:
#         simulation_index  timestep  Cer 36:1;O2  Cer 40:0;O2  Cer 40:1;O2  \
# 0                      0         0     3.014579    11.697738     2.211088
# 1                      0         1     2.979479    11.815415     2.210950
# 2                      0         2     3.045652    11.700430     2.198610
# 3                      0         3     3.077572    11.802458     2.198527
# 4                      0         4     3.079203    11.929769     2.238640
# ...                  ...       ...          ...          ...          ...
# 998995               998       995     2.322961     1.848363     2.538298
# 998996               998       996     2.487455     1.822900     2.583634
# 998997               998       997     2.475570     1.811242     2.390607
# 998998               998       998     2.653400     1.807240     2.356163
# 998999               998       999     2.797626     1.689413     2.192504
#
#         Cer 40:2;O2  Cer 41:2;O2  Cer 42:1;O2  Cer 42:2;O2   DG 35:0  ...  \
# ...

# %%
adj_matrix_pd = pd.read_csv('adjacency_matrix.csv', index_col=0)
adj_matrix = np.array(adj_matrix_pd)

np.sum(adj_matrix)

# %%
for key in sim_data.keys():
    print(key, sim_data[key].shape)
# Out:
# simulation_index (999000,)
# timestep (999000,)
# Cer 36:1;O2 (999000,)
# Cer 40:0;O2 (999000,)
# Cer 40:1;O2 (999000,)
# Cer 40:2;O2 (999000,)
# Cer 41:2;O2 (999000,)
# Cer 42:1;O2 (999000,)
# Cer 42:2;O2 (999000,)
# DG 35:0 (999000,)
# Hex2Cer 40:0;O2 (999000,)
# Hex2Cer 40:1;O2 (999000,)
# HexCer 36:1;O2 (999000,)
# HexCer 40:0;O2 (999000,)
# HexCer 40:1;O2 (999000,)
# HexCer 40:2;O2 (999000,)
# HexCer 42:1;O2 (999000,)
# HexCer 42:2;O2 (999000,)
# LPA 18:1 (999000,)
# LPC 16:0 (999000,)
# LPC 18:0 (999000,)
# LPC 18:1 (999000,)
# LPC 20:1 (999000,)
# LPC 20:4 (999000,)
# LPC 22:6 (999000,)
# LPC O-16:0 (999000,)
# LPC O-18:0 (999000,)
# LPE 18:0 (999000,)
# LPE 18:1 (999000,)
# LPE 20:0 (999000,)
# LPE 22:1 (999000,)
# LPE 22:4 (999000,)
# LPE 22:6 (999000,)
# LPG 20:1 (999000,)
# LPS 16:0 (999000,)
# PA 32:0 (999000,)
# PA 32:1 (999000,)
# PA 34:1 (999000,)
# PA 36:1 (999000,)
# PA 36:2 (999000,)
# PA 36:4 (999000,)
# PA 38:3 (999000,)
# PA 38:4 (999000,)
# PA 38:5 (999000,)
# ...
